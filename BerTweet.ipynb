# %% [markdown]
# <center><h1 style="color:red">Hate Speech Detection in Tweets and Explanation Using LLMs</h1></center>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import necessary libraries

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# !pip install emoji==0.6.0
# Out:
# Requirement already satisfied: emoji==0.6.0 in /usr/local/lib/python3.10/dist-packages (0.6.0)

# %%
import pandas as pd
import numpy as np
import re
import string
import unicodedata
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, pipeline
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report, confusion_matrix
import shap
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # 1. Data Preparation

# %% [markdown]
# ### Load the labeled tweet dataset

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/train.csv")

# Afficher les premières lignes pour vérifier l'ensemble de données
print("Dataset loaded successfully.")
print(data.head())
# Out:
# Dataset loaded successfully.
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %% [markdown]
# ###  Preprocess the tweets

# %%
# Initialiser les stopwords anglais et ajouter des stopwords personnalisés
stop_english = set(stopwords.words('english'))
custom_stopwords = set(["u", "ur", "im", "dont", "cant", "wont", "didnt", "couldnt", "youre"])
stop_english.update(custom_stopwords)

def clean_tweet(tweet):

    tweet = re.sub(r"http\S+|www\S+", '', tweet)  # Supprimer les URLs
    tweet = re.sub(r"@\w+", '', tweet)  # Supprimer les mentions
    tweet = re.sub(r"#(\w+)", r"\1", tweet)  # Gérer les hashtags
    tweet = re.sub(r"[^\w\s]", '', tweet)  # Supprimer la ponctuation
    tweet = ' '.join([word for word in tweet.split() if word not in stop_english]) # Suprrimer stopwords

    return tweet

# Nettoyer les tweets
data['tweet'] = data['tweet'].apply(clean_tweet)

# %% [markdown]
# ### Remove Duplicate Tweets

# %%
# Supprimer les lignes dupliquées en fonction des tweets nettoyés
data = data.drop_duplicates(subset='tweet', keep='first')

# Vérifiez la taille du jeu de données mis à jour
print(f"Dataset size after removing duplicates: {data.shape[0]} rows")
# Out:
# Dataset size after removing duplicates: 28456 rows

# %% [markdown]
# ### Handle Class Imbalance

# %%
# Séparer les données en classes majoritaire et minoritaire
not_hate = data[data['label'] == 0]
hate = data[data['label'] == 1]

# Réaliser l'undersampling de la classe majoritaire
not_hate_downsampled = resample(not_hate, replace=False, n_samples=hate.shape[0], random_state=42)

# Combiner les deux classes pour former le dataset équilibré
new_data = pd.concat([not_hate_downsampled, hate])

# Mélanger les données
new_data = new_data.sample(frac=1, random_state=42).reset_index(drop=True)

# Afficher la taille des classes après équilibrage
print("Taille des classes après undersampling :")
print(new_data['label'].value_counts())

print('la taille de data après undersampling :\n ', new_data.shape)

# Enregistrer le dataframe équilibré sous forme de fichier CSV
new_data.to_csv('/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/new_data.csv', index=False)
# Out:
# Taille des classes après undersampling :
# label
# 0    1865
# 1    1865
# Name: count, dtype: int64
# la taille de data après undersampling :
#   (3730, 3)

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/new_data.csv")

# %% [markdown]
# # 2. Fine-tuning a Pre-Trained Model

# %% [markdown]
# ### Load tokenizer and model

# %%
tokenizer = AutoTokenizer.from_pretrained('vinai/bertweet-base')
model = AutoModelForSequenceClassification.from_pretrained('vinai/bertweet-base', num_labels=2)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/558 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/843k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.91M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/543M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/bertweet-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Split the Dataset

# %%
# Diviser le data en Train (80%) et test (20%)
data_train, data_test = train_test_split(data, test_size=0.2, random_state=42, stratify=data['label'])

# Diviser train en train et validation
data_train, data_val = train_test_split(data_train, test_size=0.1, random_state=42, stratify=data_train['label'])

# Vérifier la répartition des ensembles
print(f"Train set size: {data_train.shape[0]} rows")
print(f"Validation set size: {data_val.shape[0]} rows")
print(f"Test set size: {data_test.shape[0]} rows")
# Out:
# Train set size: 2685 rows
# Validation set size: 299 rows
# Test set size: 746 rows

# %% [markdown]
# ### Convert data to Hugging Face's Dataset format

# %%
def convert_to_hf_dataset(data):
    return Dataset.from_pandas(data[['tweet', 'label']])

train_dataset = convert_to_hf_dataset(data_train)
val_dataset = convert_to_hf_dataset(data_val)
test_dataset = convert_to_hf_dataset(data_test)

# %% [markdown]
# ### Tokenize the dataset

# %%
def tokenize_function(examples):
    return tokenizer(examples['tweet'], truncation=True, padding='max_length', max_length=128)

train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

train_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
val_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
# Out:
# Map:   0%|          | 0/2685 [00:00<?, ? examples/s]
# Map:   0%|          | 0/299 [00:00<?, ? examples/s]
# Map:   0%|          | 0/746 [00:00<?, ? examples/s]

# %% [markdown]
# ### Define training arguments

# %%
training_args = TrainingArguments(
    output_dir='/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/results',
    eval_strategy='epoch',
    save_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/logs',
    logging_steps=10,
)

# %% [markdown]
# ### Define metrics

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = np.argmax(pred.predictions, axis=1)

    # Calculer les métriques pour chaque classe (0 et 1)
    precision, recall, f1, support = precision_recall_fscore_support(labels, preds, labels=[0, 1])

    # Calculer la précision, le rappel et le f1-score pour chaque classe
    precision_0, precision_1 = precision
    recall_0, recall_1 = recall
    f1_0, f1_1 = f1
    support_0, support_1 = support

    # Calculer l'accuracy globale
    acc = accuracy_score(labels, preds)

    return {
        'accuracy': acc,
        'precision_class_0': precision_0,
        'precision_class_1': precision_1,
        'recall_class_0': recall_0,
        'recall_class_1': recall_1,
        'f1_class_0': f1_0,
        'f1_class_1': f1_1,
        'support_class_0': support_0,
        'support_class_1': support_1
    }

# %% [markdown]
# ### Create Trainer

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# <ipython-input-20-ebd1ae3858e0>:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %% [markdown]
# ### Train and save the model

# %%
# Train the model
trainer.train()

# Save the model
model_path = '/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/BerTweet_trained_model'
tokenizer_path = '/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/BerTweet_trained_tokenizer'

model.save_pretrained(model_path)
tokenizer.save_pretrained(tokenizer_path)

print("Model and tokenizer saved successfully.")
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/content/wandb/run-20241219_092555-lefnjkw0</code>
# Syncing run <strong><a href='https://wandb.ai/hatespeechdetectionbert-ump/huggingface/runs/lefnjkw0' target="_blank">/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/results</a></strong> to <a href='https://wandb.ai/hatespeechdetectionbert-ump/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/hatespeechdetectionbert-ump/huggingface' target="_blank">https://wandb.ai/hatespeechdetectionbert-ump/huggingface</a>
#  View run at <a href='https://wandb.ai/hatespeechdetectionbert-ump/huggingface/runs/lefnjkw0' target="_blank">https://wandb.ai/hatespeechdetectionbert-ump/huggingface/runs/lefnjkw0</a>
#     <div>
#
#       <progress value='504' max='504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [504/504 3:34:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision Class 0</th>
#       <th>Precision Class 1</th>
#       <th>Recall Class 0</th>
#       <th>Recall Class 1</th>
#       <th>F1 Class 0</th>
#       <th>F1 Class 1</th>
#       <th>Support Class 0</th>
#       <th>Support Class 1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.385700</td>
#       <td>0.300684</td>
#       <td>0.879599</td>
#       <td>0.865385</td>
#       <td>0.895105</td>
#       <td>0.900000</td>
#       <td>0.859060</td>
#       <td>0.882353</td>
#       <td>0.876712</td>
#       <td>150</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.329400</td>
#       <td>0.281707</td>
#       <td>0.879599</td>
#       <td>0.938462</td>
#       <td>0.834320</td>
#       <td>0.813333</td>
#       <td>0.946309</td>
#       <td>0.871429</td>
#       <td>0.886792</td>
#       <td>150</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.199900</td>
#       <td>0.279927</td>
#       <td>0.903010</td>
#       <td>0.923077</td>
#       <td>0.884615</td>
#       <td>0.880000</td>
#       <td>0.926174</td>
#       <td>0.901024</td>
#       <td>0.904918</td>
#       <td>150</td>
#       <td>149</td>
#     </tr>
#   </tbody>
# </table><p>
# Model and tokenizer saved successfully.

# %% [markdown]
# # 3. Explainability with SHAP

# %% [markdown]
# #### 3.1.Reload the trained model and tokenizer

# %%
model_path = '/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/BerTweet_trained_model'
tokenizer_path = '/content/drive/MyDrive/Colab Notebooks/HateSpeech/BerTweet/BerTweet_trained_tokenizer'

# Charger le modèle
model = AutoModelForSequenceClassification.from_pretrained(model_path)

# Charger le tokenizer
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)

# Créer un pipeline pour la classification
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)
# Out:
# Device set to use cpu

# %% [markdown]
# #### 3.2.Préparer les données

# %%
# Sélectionner quelques exemples du jeu de données de test pour l'explicabilité
sample_data = data_test.sample(n=10, random_state=1)

# Extraire les tweets et les labels
tweets_test = sample_data['tweet'].tolist()
labels_test = sample_data['label'].tolist()

print('Exemple de jeu de données de test :\n',sample_data.head())
# Out:
# Exemple de jeu de données de test :
#           id  label                                              tweet
# 3288  17345      0                         know account hacked ok bye
# 3624  20291      0  babies officially seniors heavyhea letsummerbegin
# 2412   2930      1  democrat pay alway pay black inferior whites w...
# 734    5957      0  feeling close people orlando today prayers cas...
# 2173   2383      0                                         makes svsu

# %% [markdown]
# #### 3.3.Utiliser SHAP pour l'explication

# %%
# Créer un explainer SHAP pour le pipeline de classification
explainer = shap.Explainer(classifier)

# Calculer les valeurs SHAP pour les tweets d'exemple
shap_values = explainer(tweets_test)

# Afficher les explications pour un tweet spécifique
shap.plots.text(shap_values[0], display=True)
# Out:
# PartitionExplainer explainer:  10%|█         | 1/10 [00:00<?, ?it/s]
#   0%|          | 0/90 [00:00<?, ?it/s]
# PartitionExplainer explainer:  30%|███       | 3/10 [00:27<00:29,  4.21s/it]
#   0%|          | 0/132 [00:00<?, ?it/s]
# PartitionExplainer explainer:  40%|████      | 4/10 [00:41<00:49,  8.20s/it]
#   0%|          | 0/110 [00:00<?, ?it/s]
# PartitionExplainer explainer:  60%|██████    | 6/10 [00:59<00:32,  8.05s/it]
#   0%|          | 0/156 [00:00<?, ?it/s]
# PartitionExplainer explainer:  70%|███████   | 7/10 [01:17<00:33, 11.24s/it]
#   0%|          | 0/342 [00:00<?, ?it/s]
# PartitionExplainer explainer:  80%|████████  | 8/10 [02:05<00:46, 23.15s/it]
#   0%|          | 0/210 [00:00<?, ?it/s]
# PartitionExplainer explainer:  90%|█████████ | 9/10 [02:28<00:23, 23.21s/it]
#   0%|          | 0/132 [00:00<?, ?it/s]
# PartitionExplainer explainer: 100%|██████████| 10/10 [02:46<00:00, 21.46s/it]
#   0%|          | 0/132 [00:00<?, ?it/s]
# PartitionExplainer explainer: 11it [03:01, 18.10s/it]
# <div align='center'>
# <script>
#     document._hover_ahftrxckafnafqofpvau = '_tp_ahftrxckafnafqofpvau_output_0';
#     document._zoom_ahftrxckafnafqofpvau = undefined;
#     function _output_onclick_ahftrxckafnafqofpvau(i) {
#         var next_id = undefined;
#
#         if (document._zoom_ahftrxckafnafqofpvau !== undefined) {
#             document.getElementById(document._zoom_ahftrxckafnafqofpvau+ '_zoom').style.display = 'none';
#
#             if (document._zoom_ahftrxckafnafqofpvau === '_tp_ahftrxckafnafqofpvau_output_' + i) {
#                 document.getElementById(document._zoom_ahftrxckafnafqofpvau).style.display = 'block';
#                 document.getElementById(document._zoom_ahftrxckafnafqofpvau+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_ahftrxckafnafqofpvau).style.display = 'none';
#                 document.getElementById(document._zoom_ahftrxckafnafqofpvau+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_ahftrxckafnafqofpvau !== '_tp_ahftrxckafnafqofpvau_output_' + i) {
#             next_id = '_tp_ahftrxckafnafqofpvau_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_ahftrxckafnafqofpvau = next_id;
#     }
#     function _output_onmouseover_ahftrxckafnafqofpvau(i, el) {
#         if (document._zoom_ahftrxckafnafqofpvau !== undefined) { return; }
#         if (document._hover_ahftrxckafnafqofpvau !== undefined) {
#             document.getElementById(document._hover_ahftrxckafnafqofpvau + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_ahftrxckafnafqofpvau).style.display = 'none';
#         }
#         document.getElementById('_tp_ahftrxckafnafqofpvau_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_ahftrxckafnafqofpvau = '_tp_ahftrxckafnafqofpvau_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_ahftrxckafnafqofpvau_output_0_name"
#     onclick="_output_onclick_ahftrxckafnafqofpvau(0)"
#     onmouseover="_output_onmouseover_ahftrxckafnafqofpvau(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_ahftrxckafnafqofpvau_output_1_name"
#     onclick="_output_onclick_ahftrxckafnafqofpvau(1)"
#     onmouseover="_output_onmouseover_ahftrxckafnafqofpvau(1, this);">LABEL_1</div><br><br><div id='_tp_ahftrxckafnafqofpvau_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.75484834596294%" y1="33" x2="49.75484834596294%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.75484834596294%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.050903156706774%" y1="33" x2="36.050903156706774%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.050903156706774%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="22.346957967450603%" y1="33" x2="22.346957967450603%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.346957967450603%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="8.643012778194432%" y1="33" x2="8.643012778194432%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.643012778194432%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="63.45879353521911%" y1="33" x2="63.45879353521911%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.45879353521911%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="77.16273872447528%" y1="33" x2="77.16273872447528%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.16273872447528%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="90.86668391373146%" y1="33" x2="90.86668391373146%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.86668391373146%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="74.09292380791592%" y1="33" x2="74.09292380791592%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="74.09292380791592%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.855198</text><text x="74.09292380791592%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.855198</text><text x="74.09292380791592%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="77.1485326121661%" y1="33" x2="77.1485326121661%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.1485326121661%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.899793</text><text x="77.1485326121661%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.899793</text><text x="77.1485326121661%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="55.304668956072895%" width="21.84386365609319%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="55.304668956072895%" x2="77.1485326121661%" y1="60" y2="60" id="_fb_sieyiccwpusnzjovqwps_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="66.2266007841195%" y="71" font-size="12px" id="_fs_sieyiccwpusnzjovqwps_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.319</text><svg x="55.304668956072895%" y="40" height="20" width="21.8438636560932%">  <svg x="0" y="0" width="100%" height="100%">    <text x="5 ...

# %%
shap.plots.text(shap_values[0], display=True)
# Out:
# <div align='center'>
# <script>
#     document._hover_srngqcllywgnexwhqpdt = '_tp_srngqcllywgnexwhqpdt_output_0';
#     document._zoom_srngqcllywgnexwhqpdt = undefined;
#     function _output_onclick_srngqcllywgnexwhqpdt(i) {
#         var next_id = undefined;
#
#         if (document._zoom_srngqcllywgnexwhqpdt !== undefined) {
#             document.getElementById(document._zoom_srngqcllywgnexwhqpdt+ '_zoom').style.display = 'none';
#
#             if (document._zoom_srngqcllywgnexwhqpdt === '_tp_srngqcllywgnexwhqpdt_output_' + i) {
#                 document.getElementById(document._zoom_srngqcllywgnexwhqpdt).style.display = 'block';
#                 document.getElementById(document._zoom_srngqcllywgnexwhqpdt+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_srngqcllywgnexwhqpdt).style.display = 'none';
#                 document.getElementById(document._zoom_srngqcllywgnexwhqpdt+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_srngqcllywgnexwhqpdt !== '_tp_srngqcllywgnexwhqpdt_output_' + i) {
#             next_id = '_tp_srngqcllywgnexwhqpdt_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_srngqcllywgnexwhqpdt = next_id;
#     }
#     function _output_onmouseover_srngqcllywgnexwhqpdt(i, el) {
#         if (document._zoom_srngqcllywgnexwhqpdt !== undefined) { return; }
#         if (document._hover_srngqcllywgnexwhqpdt !== undefined) {
#             document.getElementById(document._hover_srngqcllywgnexwhqpdt + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_srngqcllywgnexwhqpdt).style.display = 'none';
#         }
#         document.getElementById('_tp_srngqcllywgnexwhqpdt_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_srngqcllywgnexwhqpdt = '_tp_srngqcllywgnexwhqpdt_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_srngqcllywgnexwhqpdt_output_0_name"
#     onclick="_output_onclick_srngqcllywgnexwhqpdt(0)"
#     onmouseover="_output_onmouseover_srngqcllywgnexwhqpdt(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_srngqcllywgnexwhqpdt_output_1_name"
#     onclick="_output_onclick_srngqcllywgnexwhqpdt(1)"
#     onmouseover="_output_onmouseover_srngqcllywgnexwhqpdt(1, this);">LABEL_1</div><br><br><div id='_tp_srngqcllywgnexwhqpdt_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.75484834596294%" y1="33" x2="49.75484834596294%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.75484834596294%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.050903156706774%" y1="33" x2="36.050903156706774%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.050903156706774%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="22.346957967450603%" y1="33" x2="22.346957967450603%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.346957967450603%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="8.643012778194432%" y1="33" x2="8.643012778194432%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.643012778194432%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="63.45879353521911%" y1="33" x2="63.45879353521911%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.45879353521911%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="77.16273872447528%" y1="33" x2="77.16273872447528%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.16273872447528%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="90.86668391373146%" y1="33" x2="90.86668391373146%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.86668391373146%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="74.09292380791592%" y1="33" x2="74.09292380791592%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="74.09292380791592%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.855198</text><text x="74.09292380791592%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.855198</text><text x="74.09292380791592%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="77.1485326121661%" y1="33" x2="77.1485326121661%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.1485326121661%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.899793</text><text x="77.1485326121661%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.899793</text><text x="77.1485326121661%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="55.304668956072895%" width="21.84386365609319%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="55.304668956072895%" x2="77.1485326121661%" y1="60" y2="60" id="_fb_ounaiaywvhbwycmbttdm_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="66.2266007841195%" y="71" font-size="12px" id="_fs_ounaiaywvhbwycmbttdm_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.319</text><svg x="55.304668956072895%" y="40" height="20" width="21.8438636560932%">  <svg x="0" y="0" width="100%" height="100%">    <text x="5 ...

# %%
shap.plots.text(shap_values[1], display=True)
# Out:
# <div align='center'>
# <script>
#     document._hover_ywemfkbjzgulkyzosehz = '_tp_ywemfkbjzgulkyzosehz_output_0';
#     document._zoom_ywemfkbjzgulkyzosehz = undefined;
#     function _output_onclick_ywemfkbjzgulkyzosehz(i) {
#         var next_id = undefined;
#
#         if (document._zoom_ywemfkbjzgulkyzosehz !== undefined) {
#             document.getElementById(document._zoom_ywemfkbjzgulkyzosehz+ '_zoom').style.display = 'none';
#
#             if (document._zoom_ywemfkbjzgulkyzosehz === '_tp_ywemfkbjzgulkyzosehz_output_' + i) {
#                 document.getElementById(document._zoom_ywemfkbjzgulkyzosehz).style.display = 'block';
#                 document.getElementById(document._zoom_ywemfkbjzgulkyzosehz+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_ywemfkbjzgulkyzosehz).style.display = 'none';
#                 document.getElementById(document._zoom_ywemfkbjzgulkyzosehz+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_ywemfkbjzgulkyzosehz !== '_tp_ywemfkbjzgulkyzosehz_output_' + i) {
#             next_id = '_tp_ywemfkbjzgulkyzosehz_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_ywemfkbjzgulkyzosehz = next_id;
#     }
#     function _output_onmouseover_ywemfkbjzgulkyzosehz(i, el) {
#         if (document._zoom_ywemfkbjzgulkyzosehz !== undefined) { return; }
#         if (document._hover_ywemfkbjzgulkyzosehz !== undefined) {
#             document.getElementById(document._hover_ywemfkbjzgulkyzosehz + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_ywemfkbjzgulkyzosehz).style.display = 'none';
#         }
#         document.getElementById('_tp_ywemfkbjzgulkyzosehz_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_ywemfkbjzgulkyzosehz = '_tp_ywemfkbjzgulkyzosehz_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_ywemfkbjzgulkyzosehz_output_0_name"
#     onclick="_output_onclick_ywemfkbjzgulkyzosehz(0)"
#     onmouseover="_output_onmouseover_ywemfkbjzgulkyzosehz(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_ywemfkbjzgulkyzosehz_output_1_name"
#     onclick="_output_onclick_ywemfkbjzgulkyzosehz(1)"
#     onmouseover="_output_onmouseover_ywemfkbjzgulkyzosehz(1, this);">LABEL_1</div><br><br><div id='_tp_ywemfkbjzgulkyzosehz_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.94546228136612%" y1="33" x2="50.94546228136612%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.94546228136612%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.71163697225177%" y1="33" x2="36.71163697225177%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.71163697225177%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="22.47781166313742%" y1="33" x2="22.47781166313742%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.47781166313742%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="8.243986354023075%" y1="33" x2="8.243986354023075%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.243986354023075%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.4</text><line x1="65.17928759048046%" y1="33" x2="65.17928759048046%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.17928759048046%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="79.41311289959482%" y1="33" x2="79.41311289959482%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.41311289959482%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="63.68217235598592%" y1="33" x2="63.68217235598592%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.68217235598592%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.768446</text><text x="63.68217235598592%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.768446</text><text x="63.68217235598592%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="73.71254477147716%" y1="33" x2="73.71254477147716%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.71254477147716%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.979852</text><text x="73.71254477147716%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.979852</text><text x="73.71254477147716%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="42.61182442889184%" width="31.10072034258531%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="59.66896034195645%" x2="73.71254477147716%" y1="60" y2="60" id="_fb_potbpnweyceprgdxgpqk_ind_1" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="66.6907525567168%" y="71" font-size="12px" id="_fs_potbpnweyceprgdxgpqk_ind_1" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.296</text><svg x="59.66896034195645%" y="40" height="20" width="14.043584429520706%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">babies</text>  </svg></svg><line x1="51.54252561368835%" x2="59.66896034195645%" y1="60" y2="60" id="_fb_potbpnweyceprgdxgpqk_ind_2" style="stroke:rgb(255. ...

# %%
# explain the predictions of the pipeline on the first two samples
explainer = shap.Explainer(classifier)  # Your pipeline
shap_values = explainer(tweets_test[:8])
# Out:
#   0%|          | 0/90 [00:00<?, ?it/s]
# PartitionExplainer explainer:  25%|██▌       | 2/8 [00:00<?, ?it/s]
#   0%|          | 0/132 [00:00<?, ?it/s]
# PartitionExplainer explainer:  50%|█████     | 4/8 [00:26<00:25,  6.40s/it]
#   0%|          | 0/110 [00:00<?, ?it/s]
# PartitionExplainer explainer:  75%|███████▌  | 6/8 [00:39<00:12,  6.04s/it]
#   0%|          | 0/156 [00:00<?, ?it/s]
# PartitionExplainer explainer:  88%|████████▊ | 7/8 [00:57<00:10, 10.05s/it]
#   0%|          | 0/342 [00:00<?, ?it/s]
# PartitionExplainer explainer: 100%|██████████| 8/8 [01:44<00:00, 22.45s/it]
#   0%|          | 0/210 [00:00<?, ?it/s]
# PartitionExplainer explainer: 9it [02:09, 18.51s/it]

# %%
# Loop through the first 8 samples
for i in range(8):
    # Display the SHAP explanation for the current sample
    shap.plots.text(shap_values[i], display=True)
# Out:
# <div align='center'>
# <script>
#     document._hover_ovpddixuwxfgcuwkqeyw = '_tp_ovpddixuwxfgcuwkqeyw_output_0';
#     document._zoom_ovpddixuwxfgcuwkqeyw = undefined;
#     function _output_onclick_ovpddixuwxfgcuwkqeyw(i) {
#         var next_id = undefined;
#
#         if (document._zoom_ovpddixuwxfgcuwkqeyw !== undefined) {
#             document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw+ '_zoom').style.display = 'none';
#
#             if (document._zoom_ovpddixuwxfgcuwkqeyw === '_tp_ovpddixuwxfgcuwkqeyw_output_' + i) {
#                 document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw).style.display = 'block';
#                 document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw).style.display = 'none';
#                 document.getElementById(document._zoom_ovpddixuwxfgcuwkqeyw+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_ovpddixuwxfgcuwkqeyw !== '_tp_ovpddixuwxfgcuwkqeyw_output_' + i) {
#             next_id = '_tp_ovpddixuwxfgcuwkqeyw_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_ovpddixuwxfgcuwkqeyw = next_id;
#     }
#     function _output_onmouseover_ovpddixuwxfgcuwkqeyw(i, el) {
#         if (document._zoom_ovpddixuwxfgcuwkqeyw !== undefined) { return; }
#         if (document._hover_ovpddixuwxfgcuwkqeyw !== undefined) {
#             document.getElementById(document._hover_ovpddixuwxfgcuwkqeyw + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_ovpddixuwxfgcuwkqeyw).style.display = 'none';
#         }
#         document.getElementById('_tp_ovpddixuwxfgcuwkqeyw_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_ovpddixuwxfgcuwkqeyw = '_tp_ovpddixuwxfgcuwkqeyw_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_ovpddixuwxfgcuwkqeyw_output_0_name"
#     onclick="_output_onclick_ovpddixuwxfgcuwkqeyw(0)"
#     onmouseover="_output_onmouseover_ovpddixuwxfgcuwkqeyw(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_ovpddixuwxfgcuwkqeyw_output_1_name"
#     onclick="_output_onclick_ovpddixuwxfgcuwkqeyw(1)"
#     onmouseover="_output_onmouseover_ovpddixuwxfgcuwkqeyw(1, this);">LABEL_1</div><br><br><div id='_tp_ovpddixuwxfgcuwkqeyw_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.75484834596294%" y1="33" x2="49.75484834596294%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.75484834596294%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.050903156706774%" y1="33" x2="36.050903156706774%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.050903156706774%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="22.346957967450603%" y1="33" x2="22.346957967450603%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.346957967450603%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="8.643012778194432%" y1="33" x2="8.643012778194432%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.643012778194432%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="63.45879353521911%" y1="33" x2="63.45879353521911%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.45879353521911%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="77.16273872447528%" y1="33" x2="77.16273872447528%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.16273872447528%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="90.86668391373146%" y1="33" x2="90.86668391373146%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.86668391373146%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="74.09292380791592%" y1="33" x2="74.09292380791592%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="74.09292380791592%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.855198</text><text x="74.09292380791592%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.855198</text><text x="74.09292380791592%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="77.1485326121661%" y1="33" x2="77.1485326121661%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.1485326121661%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.899793</text><text x="77.1485326121661%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.899793</text><text x="77.1485326121661%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="55.304668956072895%" width="21.84386365609319%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="55.304668956072895%" x2="77.1485326121661%" y1="60" y2="60" id="_fb_zvwatiyuwvgucwwfvlhu_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="66.2266007841195%" y="71" font-size="12px" id="_fs_zvwatiyuwvgucwwfvlhu_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.319</text><svg x="55.304668956072895%" y="40" height="20" width="21.8438636560932%">  <svg x="0" y="0" width="100%" height="100%">    <text x="5 ...
# <div align='center'>
# <script>
#     document._hover_fmxuecnqivtrffagmwbk = '_tp_fmxuecnqivtrffagmwbk_output_0';
#     document._zoom_fmxuecnqivtrffagmwbk = undefined;
#     function _output_onclick_fmxuecnqivtrffagmwbk(i) {
#         var next_id = undefined;
#
#         if (document._zoom_fmxuecnqivtrffagmwbk !== undefined) {
#             document.getElementById(document._zoom_fmxuecnqivtrffagmwbk+ '_zoom').style.display = 'none';
#
#             if (document._zoom_fmxuecnqivtrffagmwbk === '_tp_fmxuecnqivtrffagmwbk_output_' + i) {
#                 document.getElementById(document._zoom_fmxuecnqivtrffagmwbk).style.display = 'block';
#                 document.getElementById(document._zoom_fmxuecnqivtrffagmwbk+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_fmxuecnqivtrffagmwbk).style.display = 'none';
#                 document.getElementById(document._zoom_fmxuecnqivtrffagmwbk+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_fmxuecnqivtrffagmwbk !== '_tp_fmxuecnqivtrffagmwbk_output_' + i) {
#             next_id = '_tp_fmxuecnqivtrffagmwbk_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_fmxuecnqivtrffagmwbk = next_id;
#     }
#     function _output_onmouseover_fmxuecnqivtrffagmwbk(i, el) {
#         if (document._zoom_fmxuecnqivtrffagmwbk !== undefined) { return; }
#         if (document._hover_fmxuecnqivtrffagmwbk !== undefined) {
#             document.getElementById(document._hover_fmxuecnqivtrffagmwbk + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_fmxuecnqivtrffagmwbk).style.display = 'none';
#         }
#         document.getElementById('_tp_fmxuecnqivtrffagmwbk_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_fmxuecnqivtrffagmwbk = '_tp_fmxuecnqivtrffagmwbk_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_fmxuecnqivtrffagmwbk_output_0_name"
#     onclick="_output_onclick_fmxuecnqivtrffagmwbk(0)"
#     onmouseover="_output_onmouseover_fmxuecnqivtrffagmwbk(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_fmxuecnqivtrffagmwbk_output_1_name"
#     onclick="_output_onclick_fmxuecnqivtrffagmwbk(1)"
#     onmouseover="_output_onmouseover_fmxuecnqivtrffagmwbk(1, this);">LABEL_1</div><br><br><div id='_tp_fmxuecnqivtrffagmwbk_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.94546228136612%" y1="33" x2="50.94546228136612%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.94546228136612%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.71163697225177%" y1="33" x2="36.71163697225177%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.71163697225177%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="22.47781166313742%" y1="33" x2="22.47781166313742%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.47781166313742%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="8.243986354023075%" y1="33" x2="8.243986354023075%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.243986354023075%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.4</text><line x1="65.17928759048046%" y1="33" x2="65.17928759048046%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.17928759048046%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="79.41311289959482%" y1="33" x2="79.41311289959482%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.41311289959482%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="63.68217235598592%" y1="33" x2="63.68217235598592%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.68217235598592%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.768446</text><text x="63.68217235598592%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.768446</text><text x="63.68217235598592%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="73.71254477147716%" y1="33" x2="73.71254477147716%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.71254477147716%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.979852</text><text x="73.71254477147716%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.979852</text><text x="73.71254477147716%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="42.61182442889184%" width="31.10072034258531%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="59.66896034195645%" x2="73.71254477147716%" y1="60" y2="60" id="_fb_qfsmgratucleynbgwlur_ind_1" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="66.6907525567168%" y="71" font-size="12px" id="_fs_qfsmgratucleynbgwlur_ind_1" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.296</text><svg x="59.66896034195645%" y="40" height="20" width="14.043584429520706%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">babies</text>  </svg></svg><line x1="51.54252561368835%" x2="59.66896034195645%" y1="60" y2="60" id="_fb_qfsmgratucleynbgwlur_ind_2" style="stroke:rgb(255. ...
# <div align='center'>
# <script>
#     document._hover_akoaqdmbjfitjtvgcaoz = '_tp_akoaqdmbjfitjtvgcaoz_output_0';
#     document._zoom_akoaqdmbjfitjtvgcaoz = undefined;
#     function _output_onclick_akoaqdmbjfitjtvgcaoz(i) {
#         var next_id = undefined;
#
#         if (document._zoom_akoaqdmbjfitjtvgcaoz !== undefined) {
#             document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz+ '_zoom').style.display = 'none';
#
#             if (document._zoom_akoaqdmbjfitjtvgcaoz === '_tp_akoaqdmbjfitjtvgcaoz_output_' + i) {
#                 document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz).style.display = 'block';
#                 document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz).style.display = 'none';
#                 document.getElementById(document._zoom_akoaqdmbjfitjtvgcaoz+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_akoaqdmbjfitjtvgcaoz !== '_tp_akoaqdmbjfitjtvgcaoz_output_' + i) {
#             next_id = '_tp_akoaqdmbjfitjtvgcaoz_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_akoaqdmbjfitjtvgcaoz = next_id;
#     }
#     function _output_onmouseover_akoaqdmbjfitjtvgcaoz(i, el) {
#         if (document._zoom_akoaqdmbjfitjtvgcaoz !== undefined) { return; }
#         if (document._hover_akoaqdmbjfitjtvgcaoz !== undefined) {
#             document.getElementById(document._hover_akoaqdmbjfitjtvgcaoz + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_akoaqdmbjfitjtvgcaoz).style.display = 'none';
#         }
#         document.getElementById('_tp_akoaqdmbjfitjtvgcaoz_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_akoaqdmbjfitjtvgcaoz = '_tp_akoaqdmbjfitjtvgcaoz_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_akoaqdmbjfitjtvgcaoz_output_0_name"
#     onclick="_output_onclick_akoaqdmbjfitjtvgcaoz(0)"
#     onmouseover="_output_onmouseover_akoaqdmbjfitjtvgcaoz(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_akoaqdmbjfitjtvgcaoz_output_1_name"
#     onclick="_output_onclick_akoaqdmbjfitjtvgcaoz(1)"
#     onmouseover="_output_onmouseover_akoaqdmbjfitjtvgcaoz(1, this);">LABEL_1</div><br><br><div id='_tp_akoaqdmbjfitjtvgcaoz_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="46.51611510346174%" y1="33" x2="46.51611510346174%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="46.51611510346174%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.4</text><line x1="32.12473808114968%" y1="33" x2="32.12473808114968%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="32.12473808114968%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.2</text><line x1="17.733361058837616%" y1="33" x2="17.733361058837616%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="17.733361058837616%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="60.907492125773814%" y1="33" x2="60.907492125773814%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="60.907492125773814%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.6</text><line x1="75.29886914808588%" y1="33" x2="75.29886914808588%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="75.29886914808588%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.8</text><line x1="89.69024617039793%" y1="33" x2="89.69024617039793%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.69024617039793%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="67.29227382464052%" y1="33" x2="67.29227382464052%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="67.29227382464052%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.688731</text><text x="67.29227382464052%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.688731</text><text x="67.29227382464052%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="17.733361058837616%" y1="33" x2="17.733361058837616%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="17.733361058837616%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="17.733361058837616%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="17.733361058837616%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="7.085469573623178%" width="10.647891485214437%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="12.273077308191146%" x2="17.733361058837616%" y1="60" y2="60" id="_fb_jquqtyfaddrofsteptcv_ind_3" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="15.003219183514382%" y="71" font-size="12px" id="_fs_jquqtyfaddrofsteptcv_ind_3" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.076</text><svg x="12.273077308191146%" y="40" height="20" width="5.46028375064647%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">alway</text>  </svg></svg><line x1="7.085469573623178%" x2="12.273077308191146%" y1="60" y2="60" id="_fb_jquqtyfaddrofsteptcv_ind_10" style="stroke:rgb(255.0, 0 ...
# <div align='center'>
# <script>
#     document._hover_smtrqmucfrhpmnltishg = '_tp_smtrqmucfrhpmnltishg_output_0';
#     document._zoom_smtrqmucfrhpmnltishg = undefined;
#     function _output_onclick_smtrqmucfrhpmnltishg(i) {
#         var next_id = undefined;
#
#         if (document._zoom_smtrqmucfrhpmnltishg !== undefined) {
#             document.getElementById(document._zoom_smtrqmucfrhpmnltishg+ '_zoom').style.display = 'none';
#
#             if (document._zoom_smtrqmucfrhpmnltishg === '_tp_smtrqmucfrhpmnltishg_output_' + i) {
#                 document.getElementById(document._zoom_smtrqmucfrhpmnltishg).style.display = 'block';
#                 document.getElementById(document._zoom_smtrqmucfrhpmnltishg+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_smtrqmucfrhpmnltishg).style.display = 'none';
#                 document.getElementById(document._zoom_smtrqmucfrhpmnltishg+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_smtrqmucfrhpmnltishg !== '_tp_smtrqmucfrhpmnltishg_output_' + i) {
#             next_id = '_tp_smtrqmucfrhpmnltishg_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_smtrqmucfrhpmnltishg = next_id;
#     }
#     function _output_onmouseover_smtrqmucfrhpmnltishg(i, el) {
#         if (document._zoom_smtrqmucfrhpmnltishg !== undefined) { return; }
#         if (document._hover_smtrqmucfrhpmnltishg !== undefined) {
#             document.getElementById(document._hover_smtrqmucfrhpmnltishg + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_smtrqmucfrhpmnltishg).style.display = 'none';
#         }
#         document.getElementById('_tp_smtrqmucfrhpmnltishg_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_smtrqmucfrhpmnltishg = '_tp_smtrqmucfrhpmnltishg_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_smtrqmucfrhpmnltishg_output_0_name"
#     onclick="_output_onclick_smtrqmucfrhpmnltishg(0)"
#     onmouseover="_output_onmouseover_smtrqmucfrhpmnltishg(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_smtrqmucfrhpmnltishg_output_1_name"
#     onclick="_output_onclick_smtrqmucfrhpmnltishg(1)"
#     onmouseover="_output_onmouseover_smtrqmucfrhpmnltishg(1, this);">LABEL_1</div><br><br><div id='_tp_smtrqmucfrhpmnltishg_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.701536741936%" y1="33" x2="49.701536741936%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.701536741936%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="34.17863697130954%" y1="33" x2="34.17863697130954%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.17863697130954%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="18.65573720068308%" y1="33" x2="18.65573720068308%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.65573720068308%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="65.22443651256246%" y1="33" x2="65.22443651256246%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.22443651256246%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="80.74733628318893%" y1="33" x2="80.74733628318893%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="80.74733628318893%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="83.07169613526287%" y1="33" x2="83.07169613526287%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.07169613526287%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.929947</text><text x="83.07169613526287%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.929947</text><text x="83.07169613526287%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="87.185100585486%" y1="33" x2="87.185100585486%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="87.185100585486%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.982945</text><text x="87.185100585486%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.982945</text><text x="87.185100585486%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="72.73539764080729%" width="14.44970294467871%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="76.99126168804591%" x2="87.185100585486%" y1="60" y2="60" id="_fb_dfdntefmsznhcffeanhz_ind_2" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="82.08818113676595%" y="71" font-size="12px" id="_fs_dfdntefmsznhcffeanhz_ind_2" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.131</text><svg x="76.99126168804591%" y="40" height="20" width="10.193838897440088%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">close</text>  </svg></svg><line x1="75.6121544131197%" x2="76.99126168804591%" y1="60" y2="60" id="_fb_dfdntefmsznhcffeanhz_ind_1" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="76.3017080505828%" y="71" font-size="12px" id="_fs_dfdntefmsznhcffeanhz_ind_1" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.018</text><svg x="75 ...
# <div align='center'>
# <script>
#     document._hover_xvbehtohdrsynmcbligc = '_tp_xvbehtohdrsynmcbligc_output_0';
#     document._zoom_xvbehtohdrsynmcbligc = undefined;
#     function _output_onclick_xvbehtohdrsynmcbligc(i) {
#         var next_id = undefined;
#
#         if (document._zoom_xvbehtohdrsynmcbligc !== undefined) {
#             document.getElementById(document._zoom_xvbehtohdrsynmcbligc+ '_zoom').style.display = 'none';
#
#             if (document._zoom_xvbehtohdrsynmcbligc === '_tp_xvbehtohdrsynmcbligc_output_' + i) {
#                 document.getElementById(document._zoom_xvbehtohdrsynmcbligc).style.display = 'block';
#                 document.getElementById(document._zoom_xvbehtohdrsynmcbligc+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_xvbehtohdrsynmcbligc).style.display = 'none';
#                 document.getElementById(document._zoom_xvbehtohdrsynmcbligc+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_xvbehtohdrsynmcbligc !== '_tp_xvbehtohdrsynmcbligc_output_' + i) {
#             next_id = '_tp_xvbehtohdrsynmcbligc_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_xvbehtohdrsynmcbligc = next_id;
#     }
#     function _output_onmouseover_xvbehtohdrsynmcbligc(i, el) {
#         if (document._zoom_xvbehtohdrsynmcbligc !== undefined) { return; }
#         if (document._hover_xvbehtohdrsynmcbligc !== undefined) {
#             document.getElementById(document._hover_xvbehtohdrsynmcbligc + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_xvbehtohdrsynmcbligc).style.display = 'none';
#         }
#         document.getElementById('_tp_xvbehtohdrsynmcbligc_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_xvbehtohdrsynmcbligc = '_tp_xvbehtohdrsynmcbligc_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_xvbehtohdrsynmcbligc_output_0_name"
#     onclick="_output_onclick_xvbehtohdrsynmcbligc(0)"
#     onmouseover="_output_onmouseover_xvbehtohdrsynmcbligc(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_xvbehtohdrsynmcbligc_output_1_name"
#     onclick="_output_onclick_xvbehtohdrsynmcbligc(1)"
#     onmouseover="_output_onmouseover_xvbehtohdrsynmcbligc(1, this);">LABEL_1</div><br><br><div id='_tp_xvbehtohdrsynmcbligc_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="52.9082606065621%" y1="33" x2="52.9082606065621%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="52.9082606065621%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="35.497517519341564%" y1="33" x2="35.497517519341564%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="35.497517519341564%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="18.086774432121018%" y1="33" x2="18.086774432121018%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.086774432121018%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="70.31900369378265%" y1="33" x2="70.31900369378265%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="70.31900369378265%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="87.72974678100319%" y1="33" x2="87.72974678100319%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="87.72974678100319%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="87.85818321507567%" y1="33" x2="87.85818321507567%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="87.85818321507567%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.901475</text><text x="87.85818321507567%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.901475</text><text x="87.85818321507567%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="9.381402888510747%" y1="33" x2="9.381402888510747%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="9.381402888510747%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="9.381402888510747%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="9.381402888510747%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="8.103298841965534%" width="1.2781040465452136%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.103298841965534%" x2="9.381402888510747%" y1="60" y2="60" id="_fb_zvoyzrhbtmqxepqmcjir_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="8.74235086523814%" y="71" font-size="12px" id="_fs_zvoyzrhbtmqxepqmcjir_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.015</text><svg x="8.103298841965534%" y="40" height="20" width="1.278104046545213%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">u</text>  </svg></svg><rect transform="translate(-8,0)" x="9.381402888510747%" y="40" width="8" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792)"/><g transform="translate(-11.5,0)">  <svg x="8.103298841965534%" y="40" height="18" overflow="visible" width="30">    <path d="M 10 -9 l 6 18 L 10 25 L 0 25 L 0 -9" fill="#ffffff" style="stroke:rgb(255,255,255);stroke-width:2" />  </svg></g><rect x="8.10329884196553 ...
# <div align='center'>
# <script>
#     document._hover_hpzmdoiooliesogubtsv = '_tp_hpzmdoiooliesogubtsv_output_0';
#     document._zoom_hpzmdoiooliesogubtsv = undefined;
#     function _output_onclick_hpzmdoiooliesogubtsv(i) {
#         var next_id = undefined;
#
#         if (document._zoom_hpzmdoiooliesogubtsv !== undefined) {
#             document.getElementById(document._zoom_hpzmdoiooliesogubtsv+ '_zoom').style.display = 'none';
#
#             if (document._zoom_hpzmdoiooliesogubtsv === '_tp_hpzmdoiooliesogubtsv_output_' + i) {
#                 document.getElementById(document._zoom_hpzmdoiooliesogubtsv).style.display = 'block';
#                 document.getElementById(document._zoom_hpzmdoiooliesogubtsv+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_hpzmdoiooliesogubtsv).style.display = 'none';
#                 document.getElementById(document._zoom_hpzmdoiooliesogubtsv+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_hpzmdoiooliesogubtsv !== '_tp_hpzmdoiooliesogubtsv_output_' + i) {
#             next_id = '_tp_hpzmdoiooliesogubtsv_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_hpzmdoiooliesogubtsv = next_id;
#     }
#     function _output_onmouseover_hpzmdoiooliesogubtsv(i, el) {
#         if (document._zoom_hpzmdoiooliesogubtsv !== undefined) { return; }
#         if (document._hover_hpzmdoiooliesogubtsv !== undefined) {
#             document.getElementById(document._hover_hpzmdoiooliesogubtsv + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_hpzmdoiooliesogubtsv).style.display = 'none';
#         }
#         document.getElementById('_tp_hpzmdoiooliesogubtsv_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_hpzmdoiooliesogubtsv = '_tp_hpzmdoiooliesogubtsv_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_hpzmdoiooliesogubtsv_output_0_name"
#     onclick="_output_onclick_hpzmdoiooliesogubtsv(0)"
#     onmouseover="_output_onmouseover_hpzmdoiooliesogubtsv(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_hpzmdoiooliesogubtsv_output_1_name"
#     onclick="_output_onclick_hpzmdoiooliesogubtsv(1)"
#     onmouseover="_output_onmouseover_hpzmdoiooliesogubtsv(1, this);">LABEL_1</div><br><br><div id='_tp_hpzmdoiooliesogubtsv_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.585304470560445%" y1="33" x2="49.585304470560445%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.585304470560445%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="35.5283514996797%" y1="33" x2="35.5283514996797%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="35.5283514996797%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="21.471398528798964%" y1="33" x2="21.471398528798964%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.471398528798964%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.5</text><line x1="7.414445557918219%" y1="33" x2="7.414445557918219%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="7.414445557918219%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.9</text><line x1="63.64225744144118%" y1="33" x2="63.64225744144118%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.64225744144118%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="77.69921041232192%" y1="33" x2="77.69921041232192%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.69921041232192%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="91.75616338320268%" y1="33" x2="91.75616338320268%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="91.75616338320268%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.5</text><line x1="39.04258974239988%" y1="33" x2="39.04258974239988%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.04258974239988%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="39.04258974239988%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="39.04258974239988%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="39.04258974239988%" y1="33" x2="39.04258974239988%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.04258974239988%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="39.04258974239988%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="39.04258974239988%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="6.507098290399979%" width="32.53549145199991%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="27.322237667397133%" x2="39.04258974239988%" y1="60" y2="60" id="_fb_krvzmanpwwlnlskremzi_ind_11" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="33.18241370489851%" y="71" font-size="12px" id="_fs_krvzmanpwwlnlskremzi_ind_11" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.334</text><svg x="27.322237667397133%" y="40" height="20" width="11.72035207500275%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size= ...
# <div align='center'>
# <script>
#     document._hover_hzrhortbpmxhupjqqrsr = '_tp_hzrhortbpmxhupjqqrsr_output_0';
#     document._zoom_hzrhortbpmxhupjqqrsr = undefined;
#     function _output_onclick_hzrhortbpmxhupjqqrsr(i) {
#         var next_id = undefined;
#
#         if (document._zoom_hzrhortbpmxhupjqqrsr !== undefined) {
#             document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr+ '_zoom').style.display = 'none';
#
#             if (document._zoom_hzrhortbpmxhupjqqrsr === '_tp_hzrhortbpmxhupjqqrsr_output_' + i) {
#                 document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr).style.display = 'block';
#                 document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr).style.display = 'none';
#                 document.getElementById(document._zoom_hzrhortbpmxhupjqqrsr+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_hzrhortbpmxhupjqqrsr !== '_tp_hzrhortbpmxhupjqqrsr_output_' + i) {
#             next_id = '_tp_hzrhortbpmxhupjqqrsr_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_hzrhortbpmxhupjqqrsr = next_id;
#     }
#     function _output_onmouseover_hzrhortbpmxhupjqqrsr(i, el) {
#         if (document._zoom_hzrhortbpmxhupjqqrsr !== undefined) { return; }
#         if (document._hover_hzrhortbpmxhupjqqrsr !== undefined) {
#             document.getElementById(document._hover_hzrhortbpmxhupjqqrsr + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_hzrhortbpmxhupjqqrsr).style.display = 'none';
#         }
#         document.getElementById('_tp_hzrhortbpmxhupjqqrsr_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_hzrhortbpmxhupjqqrsr = '_tp_hzrhortbpmxhupjqqrsr_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_hzrhortbpmxhupjqqrsr_output_0_name"
#     onclick="_output_onclick_hzrhortbpmxhupjqqrsr(0)"
#     onmouseover="_output_onmouseover_hzrhortbpmxhupjqqrsr(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_hzrhortbpmxhupjqqrsr_output_1_name"
#     onclick="_output_onclick_hzrhortbpmxhupjqqrsr(1)"
#     onmouseover="_output_onmouseover_hzrhortbpmxhupjqqrsr(1, this);">LABEL_1</div><br><br><div id='_tp_hzrhortbpmxhupjqqrsr_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.09723628519636%" y1="33" x2="51.09723628519636%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.09723628519636%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.991675075941885%" y1="33" x2="33.991675075941885%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.991675075941885%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="16.886113866687403%" y1="33" x2="16.886113866687403%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.886113866687403%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="68.20279749445085%" y1="33" x2="68.20279749445085%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.20279749445085%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="85.30835870370532%" y1="33" x2="85.30835870370532%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="85.30835870370532%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="73.77448635254864%" y1="33" x2="73.77448635254864%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.77448635254864%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.765145</text><text x="73.77448635254864%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.765145</text><text x="73.77448635254864%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="8.333333262060162%" y1="33" x2="8.333333262060162%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.333333262060162%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="8.333333262060162%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="8.333333262060162%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="8.333333262060162%" width="0.0%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="translate(-8,0)" x="8.333333262060162%" y="40" width="8" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792)"/><g transform="translate(-11.5,0)">  <svg x="8.333333262060162%" y="40" height="18" overflow="visible" width="30">    <path d="M 10 -9 l 6 18 L 10 25 L 0 25 L 0 -9" fill="#ffffff" style="stroke:rgb(255,255,255);stroke-width:2" />  </svg></g><rect x="8.333333262060162%" width="65.44115309048848%" y="40" height="18" style="fill:rgb(0.0, 138.56128015770727, 250.76166088685727); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.333333262060162%" x2="16.513477398371222%" y1="60" y2="60" id="_fb_vqxqilptchtedoznxvgv_ind_1" style="stroke:rgb(0.0, 138.56128015770727, 250.76166088685727);stroke-width:2; opacity: 0"/><text x="12.423405330215692%" y="71" font-size="12px" fill="rgb(0.0, 138.56128015770727, 250.76166088685727)" id="_fs_vqxqilptchtedoznxvgv_ind_1" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">-0.096</text><svg x="8.333333262060162%" y="40" height="20" width="8.18014413631106%">  <svg x="0"  ...
# <div align='center'>
# <script>
#     document._hover_rozjkedwlrqpaugdobtf = '_tp_rozjkedwlrqpaugdobtf_output_0';
#     document._zoom_rozjkedwlrqpaugdobtf = undefined;
#     function _output_onclick_rozjkedwlrqpaugdobtf(i) {
#         var next_id = undefined;
#
#         if (document._zoom_rozjkedwlrqpaugdobtf !== undefined) {
#             document.getElementById(document._zoom_rozjkedwlrqpaugdobtf+ '_zoom').style.display = 'none';
#
#             if (document._zoom_rozjkedwlrqpaugdobtf === '_tp_rozjkedwlrqpaugdobtf_output_' + i) {
#                 document.getElementById(document._zoom_rozjkedwlrqpaugdobtf).style.display = 'block';
#                 document.getElementById(document._zoom_rozjkedwlrqpaugdobtf+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_rozjkedwlrqpaugdobtf).style.display = 'none';
#                 document.getElementById(document._zoom_rozjkedwlrqpaugdobtf+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_rozjkedwlrqpaugdobtf !== '_tp_rozjkedwlrqpaugdobtf_output_' + i) {
#             next_id = '_tp_rozjkedwlrqpaugdobtf_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_rozjkedwlrqpaugdobtf = next_id;
#     }
#     function _output_onmouseover_rozjkedwlrqpaugdobtf(i, el) {
#         if (document._zoom_rozjkedwlrqpaugdobtf !== undefined) { return; }
#         if (document._hover_rozjkedwlrqpaugdobtf !== undefined) {
#             document.getElementById(document._hover_rozjkedwlrqpaugdobtf + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_rozjkedwlrqpaugdobtf).style.display = 'none';
#         }
#         document.getElementById('_tp_rozjkedwlrqpaugdobtf_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_rozjkedwlrqpaugdobtf = '_tp_rozjkedwlrqpaugdobtf_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_rozjkedwlrqpaugdobtf_output_0_name"
#     onclick="_output_onclick_rozjkedwlrqpaugdobtf(0)"
#     onmouseover="_output_onmouseover_rozjkedwlrqpaugdobtf(0, this);">LABEL_0</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_rozjkedwlrqpaugdobtf_output_1_name"
#     onclick="_output_onclick_rozjkedwlrqpaugdobtf(1)"
#     onmouseover="_output_onmouseover_rozjkedwlrqpaugdobtf(1, this);">LABEL_1</div><br><br><div id='_tp_rozjkedwlrqpaugdobtf_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.399812539362536%" y1="33" x2="51.399812539362536%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.399812539362536%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="36.39109121462366%" y1="33" x2="36.39109121462366%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.39109121462366%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="21.382369889884778%" y1="33" x2="21.382369889884778%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="21.382369889884778%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.3</text><line x1="66.40853386410141%" y1="33" x2="66.40853386410141%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.40853386410141%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="81.4172551888403%" y1="33" x2="81.4172551888403%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.4172551888403%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.3</text><line x1="32.63891088343894%" y1="33" x2="32.63891088343894%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="32.63891088343894%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="32.63891088343894%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="32.63891088343894%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="32.63891088343894%" y1="33" x2="32.63891088343894%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="32.63891088343894%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="32.63891088343894%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0</text><text x="32.63891088343894%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LABEL_0</tspan>(inputs)</text><rect x="5.439818480573155%" width="27.199092402865784%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="22.059933349368265%" x2="32.63891088343894%" y1="60" y2="60" id="_fb_fwidxawddgeraaugiebt_ind_6" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="27.349422116403602%" y="71" font-size="12px" id="_fs_fwidxawddgeraaugiebt_ind_6" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.282</text><svg x="22.059933349368265%" y="40" height="20" width="10.578977534070674%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">sale</text>  </svg></svg><line x1="16.73343702205545%" x2="22.059933349368265%" y1="60" y2="60" id="_fb_fwidxawddgeraaugiebt_ind_4" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="19.39668518571186%" y="71" font-size="12px" id="_fs_fwidxawddgeraaugiebt_ind_4" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.142</text><svg x="16 ...

# %% [markdown]
# # 4. Model Evaluation

# %%
# Recharger le modèle et le tokenizer
model = AutoModelForSequenceClassification.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)

# Créer un pipeline pour la classification
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Faire des prédictions sur l'ensemble de test
tweets_test = data_test['tweet'].tolist()
labels_test = data_test['label'].tolist()

# Prédire les labels
predictions = classifier(tweets_test)

# Extraire les labels prédits et les probabilités
predicted_labels = [pred['label'] for pred in predictions]
predicted_labels = [1 if label == 'LABEL_1' else 0 for label in predicted_labels]

# Afficher les métriques de classification
print("Classification Report:")
print(classification_report(labels_test, predicted_labels, target_names=['Non Hate Speech', 'Hate Speech']))

# Générer la matrice de confusion
conf_matrix = confusion_matrix(labels_test, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non Hate Speech', 'Hate Speech'],
            yticklabels=['Non Hate Speech', 'Hate Speech'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Device set to use cpu
# Classification Report:
#                  precision    recall  f1-score   support
#
# Non Hate Speech       0.91      0.86      0.89       373
#     Hate Speech       0.87      0.92      0.89       373
#
#        accuracy                           0.89       746
#       macro avg       0.89      0.89      0.89       746
#    weighted avg       0.89      0.89      0.89       746

# %% [markdown]
# # 5. Local Web-Based User Interface
